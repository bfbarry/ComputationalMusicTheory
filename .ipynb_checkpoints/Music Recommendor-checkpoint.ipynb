# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # IDEAS
# - implement chroma vector
# - chord graph

# %%
rhythms = [4.4, 4.3 ...]

chords = []

rock_rhytms = []


jazz_char = {rhythm: jazz_rhythms, chords: jazz_chords}
jazz_rhythms = []
jazz_chords = ['m6', 'M6','M7', 'm7', 'ADD9']

# %%
#Incorporate all notes and respective frequencies dict to dataframe: cols for notes, rows for freq @ number 

notes_freqs = {'A': [[0, ]]}



df = pandas.dataframe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7fb52c37edc6> in <module>
# ----> 1 object(2)
#
# TypeError: object() takes no arguments

# %%
def id_chord(notes):

# %% [markdown]
# does each note have some conserved sound property through octaves?
# - Might be useful for general chord types not depending on the octave the notes are in

# %%
class note(object):
    
    def __init__(self, notes):
        

class chord(note):
    def __init__(self, notes):
        
    def getChordType(self, notes):
        
class genre(object):
    #has lists of chords used 
    
class instrument

# %%
C0 =

# %%
# From http://subsynth.sourceforge.net/freqsnote2freq.html

freqs = [] 
a = 440
for i in np.arange(12,120):
    freqs.append( a/32 * (2**((i-9)/12)) )
freqs
# Out:
# [16.351597831287414,
#  17.323914436054505,
#  18.354047994837973,
#  19.445436482630058,
#  20.60172230705437,
#  21.826764464562743,
#  23.12465141947715,
#  24.49971474885933,
#  25.95654359874657,
#  27.5,
#  29.13523509488062,
#  30.867706328507758,
#  32.70319566257483,
#  34.64782887210901,
#  36.70809598967595,
#  38.890872965260115,
#  41.20344461410874,
#  43.653528929125486,
#  46.2493028389543,
#  48.99942949771866,
#  51.91308719749314,
#  55.0,
#  58.27047018976124,
#  61.7354126570155,
#  65.40639132514966,
#  69.29565774421802,
#  73.41619197935188,
#  77.78174593052023,
#  82.4068892282175,
#  87.30705785825097,
#  92.4986056779086,
#  97.99885899543733,
#  103.82617439498628,
#  110.0,
#  116.54094037952248,
#  123.470825314031,
#  130.8127826502993,
#  138.59131548843604,
#  146.83238395870376,
#  155.56349186104046,
#  164.813778456435,
#  174.61411571650194,
#  184.9972113558172,
#  195.99771799087466,
#  207.65234878997256,
#  220.0,
#  233.0818807590449,
#  246.94165062806212,
#  261.6255653005986,
#  277.1826309768721,
#  293.66476791740763,
#  311.1269837220809,
#  329.62755691286986,
#  349.22823143300394,
#  369.9944227116344,
#  391.9954359817492,
#  415.3046975799452,
#  440.0,
#  466.1637615180898,
#  493.88330125612424,
#  523.2511306011972,
#  554.3652619537442,
#  587.3295358348153,
#  622.2539674441618,
#  659.2551138257397,
#  698.4564628660079,
#  739.9888454232688,
#  783.9908719634984,
#  830.6093951598904,
#  880.0,
#  932.3275230361796,
#  987.7666025122485,
#  1046.5022612023945,
#  1108.7305239074883,
#  1174.6590716696305,
#  1244.5079348883237,
#  1318.5102276514795,
#  1396.9129257320158,
#  1479.9776908465376,
#  1567.9817439269968,
#  1661.2187903197807,
#  1760.0,
#  1864.6550460723593,
#  1975.533205024497,
#  2093.004522404789,
#  2217.4610478149766,
#  2349.318143339261,
#  2489.0158697766474,
#  2637.020455302959,
#  2793.8258514640315,
#  2959.955381693075,
#  3135.9634878539937,
#  3322.4375806395615,
#  3520.0,
#  3729.3100921447212,
#  3951.0664100489917,
#  4186.009044809578,
#  4434.922095629955,
#  4698.636286678519,
#  4978.031739553295,
#  5274.040910605921,
#  5587.65170292806,
#  5919.91076338615,
#  6271.926975707992,
#  6644.875161279119,
#  7040.0,
#  7458.6201842894425,
#  7902.132820097983]

# %%
keys = ['C','Db','D','Eb','E','F','Gb','G','Ab','A','Bb','B']
notes = []
for n in np.arange(9):
    for i in keys:
        notes.append(i + str(n))

# %%
len(midi), len(notes)
# Out:
# (108, 108)

# %%
key_dict = dictionary = dict(zip(notes, freqs))
# Out:
# {'C0': 16.351597831287414,
#  'Db0': 17.323914436054505,
#  'D0': 18.354047994837973,
#  'Eb0': 19.445436482630058,
#  'E0': 20.60172230705437,
#  'F0': 21.826764464562743,
#  'Gb0': 23.12465141947715,
#  'G0': 24.49971474885933,
#  'Ab0': 25.95654359874657,
#  'A0': 27.5,
#  'Bb0': 29.13523509488062,
#  'B0': 30.867706328507758,
#  'C1': 32.70319566257483,
#  'Db1': 34.64782887210901,
#  'D1': 36.70809598967595,
#  'Eb1': 38.890872965260115,
#  'E1': 41.20344461410874,
#  'F1': 43.653528929125486,
#  'Gb1': 46.2493028389543,
#  'G1': 48.99942949771866,
#  'Ab1': 51.91308719749314,
#  'A1': 55.0,
#  'Bb1': 58.27047018976124,
#  'B1': 61.7354126570155,
#  'C2': 65.40639132514966,
#  'Db2': 69.29565774421802,
#  'D2': 73.41619197935188,
#  'Eb2': 77.78174593052023,
#  'E2': 82.4068892282175,
#  'F2': 87.30705785825097,
#  'Gb2': 92.4986056779086,
#  'G2': 97.99885899543733,
#  'Ab2': 103.82617439498628,
#  'A2': 110.0,
#  'Bb2': 116.54094037952248,
#  'B2': 123.470825314031,
#  'C3': 130.8127826502993,
#  'Db3': 138.59131548843604,
#  'D3': 146.83238395870376,
#  'Eb3': 155.56349186104046,
#  'E3': 164.813778456435,
#  'F3': 174.61411571650194,
#  'Gb3': 184.9972113558172,
#  'G3': 195.99771799087466,
#  'Ab3': 207.65234878997256,
#  'A3': 220.0,
#  'Bb3': 233.0818807590449,
#  'B3': 246.94165062806212,
#  'C4': 261.6255653005986,
#  'Db4': 277.1826309768721,
#  'D4': 293.66476791740763,
#  'Eb4': 311.1269837220809,
#  'E4': 329.62755691286986,
#  'F4': 349.22823143300394,
#  'Gb4': 369.9944227116344,
#  'G4': 391.9954359817492,
#  'Ab4': 415.3046975799452,
#  'A4': 440.0,
#  'Bb4': 466.1637615180898,
#  'B4': 493.88330125612424,
#  'C5': 523.2511306011972,
#  'Db5': 554.3652619537442,
#  'D5': 587.3295358348153,
#  'Eb5': 622.2539674441618,
#  'E5': 659.2551138257397,
#  'F5': 698.4564628660079,
#  'Gb5': 739.9888454232688,
#  'G5': 783.9908719634984,
#  'Ab5': 830.6093951598904,
#  'A5': 880.0,
#  'Bb5': 932.3275230361796,
#  'B5': 987.7666025122485,
#  'C6': 1046.5022612023945,
#  'Db6': 1108.7305239074883,
#  'D6': 1174.6590716696305,
#  'Eb6': 1244.5079348883237,
#  'E6': 1318.5102276514795,
#  'F6': 1396.9129257320158,
#  'Gb6': 1479.9776908465376,
#  'G6': 1567.9817439269968,
#  'Ab6': 1661.2187903197807,
#  'A6': 1760.0,
#  'Bb6': 1864.6550460723593,
#  'B6': 1975.533205024497,
#  'C7': 2093.004522404789,
#  'Db7': 2217.4610478149766,
#  'D7': 2349.318143339261,
#  'Eb7': 2489.0158697766474,
#  'E7': 2637.020455302959,
#  'F7': 2793.8258514640315,
#  'Gb7': 2959.955381693075,
#  'G7': 3135.9634878539937,
#  'Ab7': 3322.4375806395615,
#  'A7': 3520.0,
#  'Bb7': 3729.3100921447212,
#  'B7': 3951.0664100489917,
#  'C8': 4186.009044809578,
#  'Db8': 4434.922095629955,
#  'D8': 4698.636286678519,
#  'Eb8': 4978.031739553295,
#  'E8': 5274.040910605921,
#  'F8': 5587.65170292806,
#  'Gb8': 5919.91076338615,
#  'G8': 6271.926975707992,
#  'Ab8': 6644.875161279119,
#  'A8': 7040.0,
#  'Bb8': 7458.6201842894425,
#  'B8': 7902.132820097983}
